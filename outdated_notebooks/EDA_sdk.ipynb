# %% [markdown]
# # NMA CN Project

# %% [markdown]
# ## Setup
#
# **The runtime will crash and restart once when you run the first cell. This is intended behavior! Simply rerun the cell from start and it will work fine.**

# %% [markdown]
# ### Installs

# %%
# To use AllenSDK
# !python -m pip install --upgrade pip
# !pip install mindscope_utilities --upgrade
# mindscope_utilities has wrong numpy/pandas versions, so we re-install up-to-date numpy/pandas
# !pip install numpy pandas --upgrade

# Restart runtime if needed
try:
    from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache
except (ImportError, KeyError, ModuleNotFoundError):
    print('Stopping RUNTIME. Colaboratory will restart automatically. Please run again.')
    exit()
# Out:
# Requirement already satisfied: pip in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (21.1.3)
# Requirement already satisfied: mindscope_utilities in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (0.1.6)
# Requirement already satisfied: allensdk==2.11.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from mindscope_utilities) (2.11.2)
# Requirement already satisfied: flake8 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from mindscope_utilities) (3.9.2)
# Requirement already satisfied: pytest in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from mindscope_utilities) (6.2.4)
# Requirement already satisfied: statsmodels<=0.13.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.12.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (1.7.0)
# Requirement already satisfied: scikit-build<1.0.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.11.1)
# Collecting numpy<1.19.0,>=1.15.4
#   Using cached numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# Requirement already satisfied: semver in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.13.0)
# Requirement already satisfied: hdmf<2.5.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.4.0)
# Requirement already satisfied: boto3==1.17.21 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (1.17.21)
# Requirement already satisfied: ndx-events<=0.2.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.2.0)
# Requirement already satisfied: scikit-image<0.17.0,>=0.14.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.16.2)
# Requirement already satisfied: requests-toolbelt<1.0.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.9.1)
# Requirement already satisfied: requests<3.0.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.25.1)
# Requirement already satisfied: xarray<0.16.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.15.1)
# Requirement already satisfied: aiohttp==3.7.4 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (3.7.4)
# Requirement already satisfied: simplejson<4.0.0,>=3.10.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (3.17.2)
# Requirement already satisfied: marshmallow==3.0.0rc6 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (3.0.0rc6)
# Requirement already satisfied: tqdm>=4.27 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (4.61.2)
# Requirement already satisfied: tables<4.0.0,>=3.6.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (3.6.1)
# Requirement already satisfied: six<2.0.0,>=1.9.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (1.16.0)
# Collecting pandas<=0.25.3,>=0.25.1
#   Using cached pandas-0.25.3-cp38-cp38-manylinux1_x86_64.whl (10.4 MB)
# Requirement already satisfied: pynrrd<1.0.0,>=0.2.1 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.4.2)
# Requirement already satisfied: h5py<3.0.0,>=2.8 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.10.0)
# Requirement already satisfied: pynwb<2.0.0,>=1.3.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (1.4.0)
# Requirement already satisfied: seaborn<1.0.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.11.1)
# Requirement already satisfied: simpleitk<3.0.0,>=2.0.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.0.2)
# Requirement already satisfied: jinja2<2.12.0,>=2.7.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.11.3)
# Requirement already satisfied: psycopg2-binary<3.0.0,>=2.7 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.9.1)
# Requirement already satisfied: nest-asyncio==1.2.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (1.2.0)
# Requirement already satisfied: matplotlib<4.0.0,>=1.4.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (3.4.2)
# Requirement already satisfied: glymur==0.8.19 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.8.19)
# Requirement already satisfied: future<1.0.0,>=0.14.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (0.18.2)
# Requirement already satisfied: argschema<3.0.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from allensdk==2.11.2->mindscope_utilities) (2.0.2)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (3.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (21.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (5.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (1.6.3)
# Requirement already satisfied: chardet<4.0,>=2.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from aiohttp==3.7.4->allensdk==2.11.2->mindscope_utilities) (3.10.0.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from boto3==1.17.21->allensdk==2.11.2->mindscope_utilities) (0.3.7)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from boto3==1.17.21->allensdk==2.11.2->mindscope_utilities) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.21 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from boto3==1.17.21->allensdk==2.11.2->mindscope_utilities) (1.20.109)
# Requirement already satisfied: setuptools in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from glymur==0.8.19->allensdk==2.11.2->mindscope_utilities) (52.0.0.post20210125)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.21->boto3==1.17.21->allensdk==2.11.2->mindscope_utilities) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from botocore<1.21.0,>=1.20.21->boto3==1.17.21->allensdk==2.11.2->mindscope_utilities) (1.26.6)
# Requirement already satisfied: jsonschema<4,>=2.6.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from hdmf<2.5.0->allensdk==2.11.2->mindscope_utilities) (3.2.0)
# Requirement already satisfied: ruamel.yaml<1,>=0.15 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from hdmf<2.5.0->allensdk==2.11.2->mindscope_utilities) (0.17.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from jinja2<2.12.0,>=2.7.3->allensdk==2.11.2->mindscope_utilities) (2.0.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from jsonschema<4,>=2.6.0->hdmf<2.5.0->allensdk==2.11.2->mindscope_utilities) (0.17.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from matplotlib<4.0.0,>=1.4.3->allensdk==2.11.2->mindscope_utilities) (8.3.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from matplotlib<4.0.0,>=1.4.3->allensdk==2.11.2->mindscope_utilities) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from matplotlib<4.0.0,>=1.4.3->allensdk==2.11.2->mindscope_utilities) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from matplotlib<4.0.0,>=1.4.3->allensdk==2.11.2->mindscope_utilities) (2.4.7)
# Requirement already satisfied: pytz>=2017.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pandas<=0.25.3,>=0.25.1->allensdk==2.11.2->mindscope_utilities) (2021.1)
# Requirement already satisfied: idna<3,>=2.5 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from requests<3.0.0->allensdk==2.11.2->mindscope_utilities) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from requests<3.0.0->allensdk==2.11.2->mindscope_utilities) (2021.5.30)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from ruamel.yaml<1,>=0.15->hdmf<2.5.0->allensdk==2.11.2->mindscope_utilities) (0.2.6)
# Requirement already satisfied: distro in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-build<1.0.0->allensdk==2.11.2->mindscope_utilities) (1.5.0)
# Requirement already satisfied: wheel>=0.29.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-build<1.0.0->allensdk==2.11.2->mindscope_utilities) (0.36.2)
# Requirement already satisfied: packaging in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-build<1.0.0->allensdk==2.11.2->mindscope_utilities) (21.0)
# Requirement already satisfied: PyWavelets>=0.4.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk==2.11.2->mindscope_utilities) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk==2.11.2->mindscope_utilities) (2.5.1)
# Requirement already satisfied: imageio>=2.3.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from scikit-image<0.17.0,>=0.14.0->allensdk==2.11.2->mindscope_utilities) (2.9.0)
# Requirement already satisfied: decorator<5,>=4.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from networkx>=2.0->scikit-image<0.17.0,>=0.14.0->allensdk==2.11.2->mindscope_utilities) (4.4.2)
# Requirement already satisfied: patsy>=0.5 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from statsmodels<=0.13.0->allensdk==2.11.2->mindscope_utilities) (0.5.1)
# Requirement already satisfied: numexpr>=2.6.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from tables<4.0.0,>=3.6.0->allensdk==2.11.2->mindscope_utilities) (2.7.3)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from flake8->mindscope_utilities) (2.3.1)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from flake8->mindscope_utilities) (0.6.1)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from flake8->mindscope_utilities) (2.7.0)
# Requirement already satisfied: iniconfig in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pytest->mindscope_utilities) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pytest->mindscope_utilities) (1.10.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pytest->mindscope_utilities) (0.13.1)
# Requirement already satisfied: toml in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pytest->mindscope_utilities) (0.10.2)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.0
#     Uninstalling numpy-1.21.0:
#       Successfully uninstalled numpy-1.21.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.0
#     Uninstalling pandas-1.3.0:
#       Successfully uninstalled pandas-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastparquet 0.6.3 requires pandas>=1.1.0, but you have pandas 0.25.3 which is incompatible.
# Successfully installed numpy-1.18.5 pandas-0.25.3
# Requirement already satisfied: numpy in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (1.18.5)
# Collecting numpy
#   Using cached numpy-1.21.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Requirement already satisfied: pandas in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (0.25.3)
# Collecting pandas
#   Using cached pandas-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.6 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdmf 2.4.0 requires numpy<1.19.4,>=1.16, but you have numpy 1.21.0 which is incompatible.
# allensdk 2.11.2 requires numpy<1.19.0,>=1.15.4, but you have numpy 1.21.0 which is incompatible.
# allensdk 2.11.2 requires pandas<=0.25.3,>=0.25.1, but you have pandas 1.3.0 which is incompatible.
# Successfully installed numpy-1.21.0 pandas-1.3.0
# /home/seungjaeryanlee/anaconda3/envs/nma-cn/lib/python3.8/site-packages/allensdk/brain_observatory/session_api_utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# ### Imports

# %%
from collections import Counter
import os
from tqdm.autonotebook import tqdm

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns

import mindscope_utilities
import mindscope_utilities.visual_behavior_ophys as ophys

from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorOphysProjectCache

# %%
pd.set_option('display.max_columns', 500)

# %%
sns.set_context('notebook', font_scale=1.5, rc={'lines.markeredgewidth': 2})

# %%
pio.renderers.default = "iframe"

# %% [markdown]
# ### Load AllenSDK Cache

# %%
# !mkdir -p allensdk_storage
data_storage_directory = "./allensdk_storage" # Note: this path must exist on your local drive
cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=data_storage_directory)
session_table = cache.get_ophys_session_table()
experiment_table = cache.get_ophys_experiment_table()

# %% [markdown]
# ## AllenSDK Helper Class

# %% [markdown]
# This is a custom class I created to minimize the confusion with the AllenSDK.

# %%
class AllenSDKHelper:
    """
    Helper for accessing AllenSDK for the VisualBehavior dataset.
    """
    def __init__(self):
        self.data_storage_directory = "./allensdk_storage" # Note: this path must exist on your local drive
        self.cache = VisualBehaviorOphysProjectCache.from_s3_cache(cache_dir=data_storage_directory)
        self.session_table = cache.get_ophys_session_table()
        self.experiment_table = cache.get_ophys_experiment_table()

    def get_experiment_ids_from_session(self, ophys_session_id):
        """
        Get all experiment ids that belogn to a given session id.

        Parameters
        ----------
        ophys_session_id : int
            The session ID to retrieve experiment IDs from.

        Returns
        -------
        ophys_experiment_ids : list of int
            A list of experiment IDs that belong to the given session ID.
        """
        return session_table.loc[ophys_session_id]['ophys_experiment_id']


    def get_neural_df(self, ophys_session_ids=None, ophys_experiment_ids=None, include_experiment_metadata=True):
        """
        Retrieve dataframe from AllenSDK with given session IDs or experiment IDs.

        Parameters
        ----------
        ophys_session_ids : list of int, default=None
            List of session IDs to get data of.

        ophys_experiment_ids : list of int, default=None
            List of experiment IDs to get data of.

        include_experiment_metadata : bool, default=True
            If true, include experiment metadata to the dataframe.

        Returns
        -------
        df : pandas.DataFrame
            A dataframe containing all data from given session IDs or experiment IDs.
        """
        if ophys_session_ids is None and ophys_experiment_ids is None:
            raise ValueError("Specify sessions or experiments.")
        elif ophys_session_ids is not None and ophys_experiment_ids is not None:
            raise ValueError("Specify sessions or experiments, not both.")

        # Get experiment IDs from session IDs
        if ophys_experiment_ids is None:
            ophys_experiment_ids = []
            for ophys_session_id in ophys_session_ids:
                ophys_experiment_ids.extend(self.get_experiment_ids_from_session(ophys_session_id))

        # Retrieve experiments from AllenSDK
        experiment_dfs = []
        for ophys_experiment_id in tqdm(ophys_experiment_ids):
            experiment = self.cache.get_behavior_ophys_experiment(ophys_experiment_id)
            experiment_df = ophys.build_tidy_cell_df(experiment)

            if include_experiment_metadata:
                metadata_keys = [
                    'ophys_experiment_id',
                    'ophys_session_id',
                    'targeted_structure',
                    'imaging_depth',
                    'equipment_name',
                    'cre_line',
                    'mouse_id',
                    'sex',
                ]
                for metadata_key in metadata_keys:
                    experiment_df[metadata_key] = experiment.metadata[metadata_key]

            experiment_dfs.append(experiment_df)
        
        # Concatenate into a single dataframe
        df = pd.concat(experiment_dfs)

        return df


    def get_stimulus_df(self, ophys_session_id=None, ophys_experiment_id=None):
        """
        Get stimulus data of a given session. Same stimulus pattern was used for every experiment in a session.

        Parameters
        ----------
        ophys_session_id : int
            The session ID to retrieve stimulus data of.
        
        Returns
        -------
        stimulus_df : pandas.DataFrame
            The dataframe containing info about stimulus pattern throughout the session.
        """
        if ophys_session_id is None and ophys_experiment_id is None:
            raise ValueError("Specify a session or an experiment.")
        elif ophys_session_id is not None and ophys_experiment_id is not None:
            raise ValueError("Specify a session or an experiment, not both.")

        if ophys_experiment_id is None:
            ophys_experiment_id = self.get_experiment_ids_from_session(ophys_session_id)[0]
        
        experiment = self.cache.get_behavior_ophys_experiment(ophys_experiment_id)
        stimulus_df = experiment.stimulus_presentations
        # Drop the 'image_set' column to avoid confusion. It contains a unique
        # string for set of images presented in a session.
        stimulus_df = stimulus_df.drop(columns = ['image_set'])

        return stimulus_df


    def get_etr_df(self, neural_df, t, y, event_times, t_before=1, t_after=1, output_sampling_rate=10):
        """
        Get event triggered response dataframe. This is a thin wrapper of
        mindscope_utilities.event_triggered_response.

        Parameters
        ----------
        data: Pandas.DataFrame
            Input dataframe in tidy format
            Each row should be one observation
            Must contains columns representing `t` and `y` (see below)
        t : string
            Name of column in data to use as time data
        y : string
            Name of column to use as y data
        event_times: list or array of floats
            Times of events of interest.
        t_before : float, default:1
            time before each of event of interest to include in each slice
                (in same units as `t` column)
        t_after : float, default:1
            time after each event of interest to include in each slice
                (in same units as `t` column)
        output_sampling_rate : float, default:10
            desired sampling of output
                (input data will be interpolated to this sampling rate)

        Returns
        -------
        etr_df : pandas.DataFrame
            The dataframe with responses around each specified event.
        """
        etr_df = mindscope_utilities.event_triggered_response(
            data=neural_df,
            t=t,
            y=y,
            event_times=event_times,
            t_before=t_before,
            t_after=t_after,
            output_sampling_rate=output_sampling_rate,
            include_endpoint=True,
            output_format='tidy',
        )

        return etr_df


    def plot_etr_df(self, etr_df, x=None, y=None):
        """
        Plot the event trigger response using Seaborn.

        Parameters
        ----------
        etr_df : pandas.DataFrame
            A dataframe with responses around each specified event.
        x : str, default=None
            The name of the column to use for the x-axis. If not specified, the
            first column is used.
        y : str, default=None
            The name of the column to use for the y-axis. If not specified, the
            second column is used.
        """
        fig, ax = plt.subplots()
        self.plot_etr_df_on_axes(ax=ax, etr_df=etr_df, x=x, y=y)
        fig.show()


    def plot_etr_df_on_axes(self, ax, etr_df, x=None, y=None):
        """
        Plot the event trigger response using Seaborn on given axis.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
            The matplotlib axes to generate plot on.
        etr_df : pandas.DataFrame
            A dataframe with responses around each specified event.
        x : str, default=None
            The name of the column to use for the x-axis. If not specified, the
            first column is used.
        y : str, default=None
            The name of the column to use for the y-axis. If not specified, the
            second column is used.
        """
        sns.lineplot(
            data=etr_df,
            x=x if x is not None else etr_df.columns[0],
            y=y if y is not None else etr_df.columns[1],
            n_boot=500,
            ax=ax,
        )

# %%
helper = AllenSDKHelper()

# %% [markdown]
# ## Scratch

# %%
neural_df = helper.get_neural_df(ophys_session_ids=[854060305])
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
neural_df.head()
# Out:
#    timestamps  cell_roi_id  cell_specimen_id       dff  events  \
# 0    10.52216   1080852071        1086550481  0.400583     0.0
# 1    10.61538   1080852071        1086550481  0.126125     0.0
# 2    10.70860   1080852071        1086550481 -0.083087     0.0
# 3    10.80182   1080852071        1086550481  0.158960     0.0
# 4    10.89504   1080852071        1086550481  0.301507     0.0
#
#    filtered_events  ophys_experiment_id  ophys_session_id targeted_structure  \
# 0              0.0            854759890         854060305               VISp
# 1              0.0            854759890         854060305               VISp
# 2              0.0            854759890         854060305               VISp
# 3              0.0            854759890         854060305               VISp
# 4              0.0            854759890         854060305               VISp
#
#    imaging_depth equipment_name      cre_line  mouse_id sex
# 0            275         MESO.1  Sst-IRES-Cre    440631   M
# 1            275         MESO.1  Sst-IRES-Cre    440631   M
# 2            275         MESO.1  Sst-IRES-Cre    440631   M
# 3            275         MESO.1  Sst-IRES-Cre    440631   M
# 4            275         MESO.1  Sst-IRES-Cre    440631   M

# %%
single_cell_df = neural_df.query("cell_specimen_id == 1086557208")

# %%
single_cell_df.head()
# Out:
#    timestamps  cell_roi_id  cell_specimen_id       dff  events  \
# 0    10.52216   1080855724        1086557208  0.218961     0.0
# 1    10.61538   1080855724        1086557208  0.232865     0.0
# 2    10.70860   1080855724        1086557208 -0.050186     0.0
# 3    10.80182   1080855724        1086557208  0.239468     0.0
# 4    10.89504   1080855724        1086557208  0.226356     0.0
#
#    filtered_events  ophys_experiment_id  ophys_session_id targeted_structure  \
# 0              0.0            854759894         854060305               VISp
# 1              0.0            854759894         854060305               VISp
# 2              0.0            854759894         854060305               VISp
# 3              0.0            854759894         854060305               VISp
# 4              0.0            854759894         854060305               VISp
#
#    imaging_depth equipment_name      cre_line  mouse_id sex
# 0            179         MESO.1  Sst-IRES-Cre    440631   M
# 1            179         MESO.1  Sst-IRES-Cre    440631   M
# 2            179         MESO.1  Sst-IRES-Cre    440631   M
# 3            179         MESO.1  Sst-IRES-Cre    440631   M
# 4            179         MESO.1  Sst-IRES-Cre    440631   M

# %%
stimulus_df = helper.get_stimulus_df(ophys_session_id=854060305)

# %%
stimulus_df.head()
# Out:
#                            duration  end_frame  image_index image_name  index  \
# stimulus_presentations_id
# 0                           0.25021    18001.0            0      im000      0
# 1                           0.25020    18046.0            0      im000      1
# 2                           0.25021    18091.0            0      im000      2
# 3                           0.25020    18136.0            0      im000      3
# 4                           0.25021    18181.0            0      im000      4
#
#                            omitted  start_frame  start_time  stop_time  \
# stimulus_presentations_id
# 0                            False        17986   310.55053  310.80074
# 1                            False        18031   311.30115  311.55135
# 2                            False        18076   312.05179  312.30200
# 3                            False        18121   312.80242  313.05262
# 4                            False        18166   313.55303  313.80324
#
#                            is_change
# stimulus_presentations_id
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False

# %%
stimulus_df.query("omitted").head(10)
# Out:
#                            duration  end_frame  image_index image_name  index  \
# stimulus_presentations_id
# 61                             0.25        NaN            8    omitted      0
# 105                            0.25        NaN            8    omitted      1
# 113                            0.25        NaN            8    omitted      2
# 128                            0.25        NaN            8    omitted      3
# 143                            0.25        NaN            8    omitted      4
# 172                            0.25        NaN            8    omitted      5
# 174                            0.25        NaN            8    omitted      6
# 243                            0.25        NaN            8    omitted      7
# 254                            0.25        NaN            8    omitted      8
# 267                            0.25        NaN            8    omitted      9
#
#                            omitted  start_frame  start_time  stop_time  \
# stimulus_presentations_id
# 61                            True        20731   356.33793  356.58793
# 105                           True        22711   389.36492  389.61492
# 113                           True        23071   395.36980  395.61980
# 128                           True        23746   406.62904  406.87904
# 143                           True        24422   417.90490  418.15490
# 172                           True        25727   439.67265  439.92265
# 174                           True        25817   441.17391  441.42391
# 243                           True        28923   492.98288  493.23288
# 254                           True        29418   501.23958  501.48958
# 267                           True        30003   510.99759  511.24759
#
#                            is_change
# stimulus_presentations_id
# 61                             False
# 105                            False
# 113                            False
# 128                            False
# 143                            False
# 172                            False
# 174                            False
# 243                            False
# 254                            False
# 267                            False

# %%
cell_ids = neural_df['cell_specimen_id'].unique()
cell_id = cell_ids[11]

# %%
etr_df = helper.get_etr_df(
    neural_df = neural_df.query('cell_specimen_id == @cell_id'),
    t='timestamps',
    y='dff',
    event_times=stimulus_df.query('omitted')['start_time'],
    t_before=3,
    t_after=3,
    output_sampling_rate=50,
)

# %%
fig, ax = plt.subplots()
sns.lineplot(
    data=etr_df,
    x="time",
    y="dff",
    n_boot=500,
    ax=ax,
)
# Out:
# <AxesSubplot:xlabel='time', ylabel='dff'>

# %%
helper.plot_etr_df(etr_df)

# %%
np.random.seed(0)
fig, ax = plt.subplots()
for cell_id in tqdm(np.random.choice(cell_ids, size=10, replace=False)):
    etr_df = helper.get_etr_df(
        neural_df = neural_df.query('cell_specimen_id == @cell_id'),
        t='timestamps',
        y='dff',
        event_times=stimulus_df.query('omitted')['start_time'],
        t_before=3,
        t_after=3,
        output_sampling_rate=50,
    )
    helper.plot_etr_df_on_axes(ax, etr_df)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
mean_dff_by_experiment = (
    neural_df
        .groupby(['ophys_experiment_id','timestamps'])['dff']
        .mean()
        .reset_index()
)

# %%
# set up a new figure and axis
fig, ax = plt.subplots()

# make an empty list that we will fill with strings for the legend
legend_text = []

# iterate over every `ophys_experiment_id`
for ophys_experiment_id in tqdm(helper.get_experiment_ids_from_session(ophys_session_id=854060305)):
    etr_df = helper.get_etr_df(
        neural_df=mean_dff_by_experiment.query('ophys_experiment_id == @ophys_experiment_id'),
        t='timestamps',
        y='dff',
        event_times=stimulus_df.query('omitted')['start_time'],
        t_before=3,
        t_after=3,
        output_sampling_rate=50,
    )
    helper.plot_etr_df_on_axes(ax, etr_df)
    
    # get some metadata to add to the legend
    this_exp = neural_df.query('ophys_experiment_id == @ophys_experiment_id')
    structure = this_exp['targeted_structure'].iloc[0]
    depth = this_exp['imaging_depth'].iloc[0]

    # append a string to our list of legend text
    legend_text.append('structure = {}\ndepth = {} um'.format(structure, depth))
    
# Put the legend out of the figure
plt.legend(legend_text, bbox_to_anchor=(1.05, 1))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# ## Scratch

# %%
helper.session_table.head(5)
# Out:
#                  equipment_name  \
# ophys_session_id
# 951410079                MESO.1
# 952430817                MESO.1
# 954954402                MESO.1
# 955775716                MESO.1
# 957020350                MESO.1
#
#                                                   full_genotype  mouse_id  \
# ophys_session_id
# 951410079         Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 952430817         Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 954954402         Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 955775716         Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 957020350         Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
#
#                                reporter_line     driver_line sex  age_in_days  \
# ophys_session_id
# 951410079         Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F        206.0
# 952430817         Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F        209.0
# 954954402         Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F        210.0
# 955775716         Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F        212.0
# 957020350         Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F        213.0
#
#                       cre_line indicator  session_number  \
# ophys_session_id
# 951410079         Sst-IRES-Cre   GCaMP6f             1.0
# 952430817         Sst-IRES-Cre   GCaMP6f             2.0
# 954954402         Sst-IRES-Cre   GCaMP6f             3.0
# 955775716         Sst-IRES-Cre   GCaMP6f             3.0
# 957020350         Sst-IRES-Cre   GCaMP6f             4.0
#
#                   prior_exposures_to_session_type  \
# ophys_session_id
# 951410079                                       0
# 952430817                                       0
# 954954402                                       0
# 955775716                                       1
# 957020350                                       0
#
#                   prior_exposures_to_image_set  prior_exposures_to_omissions  \
# ophys_session_id
# 951410079                                 65.0                             0
# 952430817                                 66.0                             1
# 954954402                                 67.0                             2
# 955775716                                 68.0                             3
# 957020350                                  0.0                             4
#
#                   behavior_session_id  \
# ophys_session_id
# 951410079                   951520319
# 952430817                   952554548
# 954954402                   953982960
# 955775716                   956010809
# 957020350                   957032492
#
#                                                 ophys_experiment_id  \
# ophys_session_id
# 951410079         [951980471, 951980473, 951980475, 951980479, 9...
# 952430817              [953659743, 953659745, 953659749, 953659752]
# 954954402         [958527464, 958527471, 958527474, 958527479, 9...
# 955775716                         [956941841, 956941844, 956941846]
# 957020350         [957759562, 957759564, 957759566, 957759570, 9...
#
#                                                  ophys_container_id  \
# ophys_session_id
# 951410079         [1018028339, 1018028342, 1018028345, 101802835...
# 952430817          [1018028339, 1018028345, 1018028354, 1018028357]
# 954954402         [1018028339, 1018028342, 1018028345, 101802835...
# 955775716                      [1018028339, 1018028342, 1018028345]
# 957020350         [1018028339, 1018028342, 1018028345, 101802835...
#
#                               project_code         date_of_acquisition  \
# ophys_session_id
# 951410079         VisualBehaviorMultiscope  2019-09-20 09:45:29.897856
# 952430817         VisualBehaviorMultiscope  2019-09-23 08:13:07.627573
# 954954402         VisualBehaviorMultiscope  2019-09-24 16:00:00.000000
# 955775716         VisualBehaviorMultiscope  2019-09-26 08:44:37.199778
# 957020350         VisualBehaviorMultiscope  2019-09-27 08:28:05.415005
#
#                               session_type
# ophys_session_id
# 951410079                 OPHYS_1_images_A
# 952430817         OPHYS_2_images_A_passive
# 954954402                 OPHYS_3_images_A
# 955775716                 OPHYS_3_images_A
# 957020350                 OPHYS_4_images_B

# %%
# helper.experiment_table.head(8)
helper.experiment_table.query("ophys_session_id == 951410079")
# Out:
#                     equipment_name  \
# ophys_experiment_id
# 951980471                   MESO.1
# 951980484                   MESO.1
# 951980473                   MESO.1
# 951980479                   MESO.1
# 951980475                   MESO.1
# 951980481                   MESO.1
# 951980486                   MESO.1
#
#                                                      full_genotype  mouse_id  \
# ophys_experiment_id
# 951980471            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980484            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980473            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980479            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980475            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980481            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
# 951980486            Sst-IRES-Cre/wt;Ai148(TIT2L-GC6f-ICL-tTA2)/wt    457841
#
#                                   reporter_line     driver_line sex  \
# ophys_experiment_id
# 951980471            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980484            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980473            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980479            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980475            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980481            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
# 951980486            Ai148(TIT2L-GC6f-ICL-tTA2)  [Sst-IRES-Cre]   F
#
#                      age_in_days      cre_line indicator  session_number  \
# ophys_experiment_id
# 951980471                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980484                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980473                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980479                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980475                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980481                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
# 951980486                  206.0  Sst-IRES-Cre   GCaMP6f             1.0
#
#                      prior_exposures_to_session_type  \
# ophys_experiment_id
# 951980471                                          0
# 951980484                                          0
# 951980473                                          0
# 951980479                                          0
# 951980475                                          0
# 951980481                                          0
# 951980486                                          0
#
#                      prior_exposures_to_image_set  \
# ophys_experiment_id
# 951980471                                    65.0
# 951980484                                    65.0
# 951980473                                    65.0
# 951980479                                    65.0
# 951980475                                    65.0
# 951980481                                    65.0
# 951980486                                    65.0
#
#                      prior_exposures_to_omissions  ophys_session_id  \
# ophys_experiment_id
# 951980471                                       0         951410079
# 951980484                                       0         951410079
# 951980473                                       0         951410079
# 951980479                                       0         951410079
# 951980475                                       0         951410079
# 951980481                                       0         951410079
# 951980486                                       0         951410079
#
#                      behavior_session_id  ophys_container_id  \
# ophys_experiment_id
# 951980471                      951520319          1018028342
# 951980484                      951520319          1018028351
# 951980473                      951520319          1018028345
# 951980479                      951520319          1018028354
# 951980475                      951520319          1018028339
# 951980481                      951520319          1018028357
# 951980486                      951520319          1018028360
#
#                                  project_code  imaging_depth  \
# ophys_experiment_id
# 951980471            VisualBehaviorMultiscope            150
# 951980484            VisualBehaviorMultiscope             75
# 951980473            VisualBehaviorMultiscope            225
# 951980479            VisualBehaviorMultiscope            150
# 951980475            VisualBehaviorMultiscope             75
# 951980481            VisualBehaviorMultiscope            225
# 951980486            VisualBehaviorMultiscope            300
#
#                     targeted_structure         date_of_acquisition  \
# ophys_experiment_id
# 951980471                         VISp  2019-09-20 09:45:29.897856
# 951980484                         VISl  2019-09-20 09:45:29.897856
# 951980473                         VISp  2019-09-20 09:45:29.897856
# 951980479                         VISl  2019-09-20 09:45:29.897856
# 951980475                         VISp  2019-09-20 09:45:29.897856
# 951980481                         VISl  2019-09-20 09:45:29.897856
# 951980486                         VISl  2019-09-20 09:45:29.897856
#
#                          session_type     file_id
# ophys_experiment_id
# 951980471            OPHYS_1_images_A  1085394308
# 951980484            OPHYS_1_images_A  1085400876
# 951980473            OPHYS_1_images_A  1085400919
# 951980479            OPHYS_1_images_A  1085400977
# 951980475            OPHYS_1_images_A  1085400920
# 951980481            OPHYS_1_images_A  1085400972
# 951980486            OPHYS_1_images_A  1085400869
